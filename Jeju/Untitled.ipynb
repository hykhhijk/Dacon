# %% [markdown]
# # Load libraries & data

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import os
import random
from autogluon.timeseries import TimeSeriesDataFrame, TimeSeriesPredictor

# %% [markdown]
# ## set seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## Load data

# %%
path = "/mnt/d/data/jeju"

train_df = pd.read_csv(os.path.join(path, './train.csv'))
test_df = pd.read_csv(os.path.join(path, './test.csv'))

# %% [markdown]
# # Preprocess

# %%
new_train = train_df[['ID','timestamp','supply(kg)', 'price(원/kg)']]
new_test = test_df[['ID','timestamp']]

new_train['item_id'] = new_train.ID.str[0:6]
# Out:
# /tmp/ipykernel_13846/364219925.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['item_id'] = new_train.ID.str[0:6]

# %% [markdown]
# # Train autogluon

# %%
new_train
# Out:
#                     ID   timestamp  supply(kg)  price(원/kg) item_id
# 0      TG_A_J_20190101  2019-01-01         0.0          0.0  TG_A_J
# 1      TG_A_J_20190102  2019-01-02         0.0          0.0  TG_A_J
# 2      TG_A_J_20190103  2019-01-03     60601.0       1728.0  TG_A_J
# 3      TG_A_J_20190104  2019-01-04     25000.0       1408.0  TG_A_J
# 4      TG_A_J_20190105  2019-01-05     32352.0       1250.0  TG_A_J
# ...                ...         ...         ...          ...     ...
# 59392  RD_F_J_20230227  2023-02-27    452440.0        468.0  RD_F_J
# 59393  RD_F_J_20230228  2023-02-28    421980.0        531.0  RD_F_J
# 59394  RD_F_J_20230301  2023-03-01    382980.0        574.0  RD_F_J
# 59395  RD_F_J_20230302  2023-03-02    477220.0        523.0  RD_F_J
# 59396  RD_F_J_20230303  2023-03-03    427520.0        529.0  RD_F_J
#
# [59397 rows x 5 columns]

# %%
predictor.leaderboard(new_train, silent=True)
# Out:
# Additional data provided, testing on additional data. Resulting leaderboard will be sorted according to test score (`score_test`).
#                     model  score_test   score_val  pred_time_test  \
# 0        WeightedEnsemble -705.743037 -709.940939        1.555315
# 1                  DeepAR -720.781044 -728.319343        0.844896
# 2            AutoETS_FULL -797.059173         NaN        1.770588
# 3                 AutoETS -797.059173 -797.059173       19.861295
# 4        RecursiveTabular -810.212523 -810.212523        0.658655
# 5   RecursiveTabular_FULL -825.170948         NaN        0.575578
# 6              Theta_FULL -838.834688         NaN        1.861221
# 7                   Theta -838.834688 -838.834688       25.850180
# 8      SeasonalNaive_FULL -843.925825         NaN        0.054764
# 9           SeasonalNaive -843.925825 -843.925825        0.054855
# 10             Naive_FULL -997.063356         NaN        0.054919
# 11                  Naive -997.063356 -997.063356        0.045835
#
#     pred_time_val  fit_time_marginal  fit_order
# 0        5.403187           1.097517          7
# 1        0.764221         155.688102          6
# 2             NaN           0.000163         11
# 3       10.688277           0.029049          4
# 4        1.068097          11.392555          5
# 5             NaN           2.275115         12
# 6             NaN           0.000122         10
# 7       20.429361           0.027956          3
# 8             NaN           0.000228          9
# 9        0.042894           0.032684          2
# 10            NaN           0.000133          8
# 11       3.570869           0.035323          1

# %%
data = TimeSeriesDataFrame(new_train.drop(columns=['ID']))
predictor = TimeSeriesPredictor( 
    prediction_length=28,
    target="price(원/kg)",
    eval_metric="RMSE",
)
# seed 고정
predictor.fit(data)
# Out:
# ================ TimeSeriesPredictor ================
# TimeSeriesPredictor.fit() called
# Fitting with arguments:
# {'enable_ensemble': True,
#  'evaluation_metric': 'RMSE',
#  'excluded_model_types': None,
#  'hyperparameter_tune_kwargs': None,
#  'hyperparameters': 'default',
#  'num_val_windows': 1,
#  'prediction_length': 28,
#  'random_seed': 42,
#  'target': 'price(원/kg)',
#  'time_limit': None,
#  'verbosity': 2}
# Provided training data set with 59397 rows, 39 items (item = single time series). Average time series length is 1523.0. Data frequency is 'D'.
# =====================================================
# Global seed set to 42
# AutoGluon will save models to AutogluonModels/ag-20231114_133632
# AutoGluon will gauge predictive performance using evaluation metric: 'RMSE'
# 	This metric's sign has been flipped to adhere to being 'higher is better'. The reported score can be multiplied by -1 to get the metric value.
#
# Provided dataset contains following columns:
# 	target:           'price(원/kg)'
# 	past covariates:  ['supply(kg)']
#
# Starting training. Start time is 2023-11-14 22:36:32
# Models that will be trained: ['Naive', 'SeasonalNaive', 'Theta', 'AutoETS', 'RecursiveTabular', 'DeepAR']
# Training timeseries model Naive.
# 	-997.0634     = Validation score (-RMSE)
# 	0.04    s     = Training runtime
# 	3.57    s     = Validation (prediction) runtime
# Training timeseries model SeasonalNaive.
# 	-843.9258     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	0.04    s     = Validation (prediction) runtime
# Training timeseries model Theta.
# 	-838.8347     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	20.43   s     = Validation (prediction) runtime
# Training timeseries model AutoETS.
# 	-797.0592     = Validation score (-RMSE)
# 	0.03    s     = Training runtime
# 	10.69   s     = Validation (prediction) runtime
# Training timeseries model RecursiveTabular.
# 	-810.2125     = Validation score (-RMSE)
# 	11.39   s     = Training runtime
# 	1.07    s     = Validation (prediction) runtime
# Training timeseries model DeepAR.
# 	-728.3193     = Validation score (-RMSE)
# 	155.69  s     = Training runtime
# 	0.76    s     = Validation (prediction) runtime
# Fitting simple weighted ensemble.
# 	-709.9409     = Validation score (-RMSE)
# 	1.10    s     = Training runtime
# 	5.40    s     = Validation (prediction) runtime
# Training complete. Models trained: ['Naive', 'SeasonalNaive', 'Theta', 'AutoETS', 'RecursiveTabular', 'DeepAR', 'WeightedEnsemble']
# Total runtime: 205.31 s
# Best model: WeightedEnsemble
# Best model score: -709.9409

# %%
predictor.refit_full()
# Out:
# 	WARNING: refit_full functionality for TimeSeriesPredictor is experimental and is not yet supported by all models.
# Refitting models via `refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix '_FULL' and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `fit` call.
# Fitting model: Naive_FULL | Skipping fit via cloning parent ...
# Fitting model: SeasonalNaive_FULL | Skipping fit via cloning parent ...
# Fitting model: Theta_FULL | Skipping fit via cloning parent ...
# Fitting model: AutoETS_FULL | Skipping fit via cloning parent ...
# Fitting model: RecursiveTabular_FULL
# 	2.28    s     = Training runtime
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 predictor.refit_full()                                                                       │
# │   2                                                                                              │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/predictor.py: │
# │ 899 in refit_full                                                                                │
# │                                                                                                  │
# │   896 │   │   │   "\tThis process is not bound by time_limit, but should take less time than t   │
# │   897 │   │   )                                                                                  │
# │   898 │   │   model_best = self.get_model_best()                                                 │
# │ ❱ 899 │   │   refit_full_dict = self._learner.refit_full(model=model)                            │
# │   900 │   │                                                                                      │
# │   901 │   │   if set_best_to_refit_full:                                                         │
# │   902 │   │   │   if model_best in refit_full_dict:                                              │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/learner.py:23 │
# │ 5 in refit_full                                                                                  │
# │                                                                                                  │
# │   232 │   │   return learner_info                                                                │
# │   233 │                                                                                          │
# │   234 │   def refit_full(self, model: str = "all") -> Dict[str, str]:                            │
# │ ❱ 235 │   │   return self.load_trainer().refit_full(model=model)                                 │
# │   236                                                                                            │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/trainer/abstr │
# │ act_trainer.py:1113 in refit_full                                                                │
# │                                                                                                  │
# │   1110 │   │   │   │   valid_model_set.append(name)                                              │
# │   1111 │   │                                                                                     │
# │   1112 │   │   if valid_model_set:                                                               │
# │ ❱ 1113 │   │   │   models_trained_full = self.refit_single_full(models=valid_model_set)          │
# │   1114 │   │   else:                                                                             │
# │   1115 │   │   │   models_trained_full = []                                                      │
# │   1116                                                                                           │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/trainer/abstr │
# │ act_trainer.py:1074 in refit_single_full                                                         │
# │                                                                                                  │
# │   1071 │   │   │   │   │   model=model_full,                                                     │
# │   1072 │   │   │   │   )                                                                         │
# │   1073 │   │   │   else:                                                                         │
# │ ❱ 1074 │   │   │   │   model_full = model.convert_to_refit_full_via_copy()                       │
# │   1075 │   │   │   │   logger.info(f"Fitting model: {model_full.name} | Skipping fit via clonin  │
# │   1076 │   │   │   │   models_trained = [model_full.name]                                        │
# │   1077 │   │   │   │   if isinstance(model_full, AbstractTimeSeriesEnsembleModel):               │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/models/multi_ │
# │ window/multi_window_model.py:209 in convert_to_refit_full_via_copy                               │
# │                                                                                                  │
# │   206 │                                                                                          │
# │   207 │   def convert_to_refit_full_via_copy(self) -> AbstractTimeSeriesModel:                   │
# │   208 │   │   # refit_model is an instance of base model type, not MultiWindowBacktestingModel   │
# │ ❱ 209 │   │   refit_model = self.most_recent_model.convert_to_refit_full_via_copy()              │
# │   210 │   │   refit_model.rename(self.name + ag.constants.REFIT_FULL_SUFFIX)                     │
# │   211 │   │   return refit_model                                                                 │
# │   212                                                                                            │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/models/abstra │
# │ ct/abstract_timeseries_model.py:454 in convert_to_refit_full_via_copy                            │
# │                                                                                                  │
# │   451 │   │   return None                                                                        │
# │   452 │                                                                                          │
# │   453 │   def convert_to_refit_full_via_copy(self) -> "AbstractTimeSeriesModel":                 │
# │ ❱ 454 │   │   refit_model = super().convert_to_refit_full_via_copy()                             │
# │   455 │   │   refit_model.val_score = None                                                       │
# │   456 │   │   refit_model.predict_time = None                                                    │
# │   457 │   │   return refit_model                                                                 │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abs │
# │ tract_model.py:1283 in convert_to_refit_full_via_copy                                            │
# │                                                                                                  │
# │   1280 │   │   __path_refit = self.path                                                          │
# │   1281 │   │   self.save(path=self.path, verbose=False)                                          │
# │   1282 │   │   self.rename(__name)                                                               │
# │ ❱ 1283 │   │   return self.load(path=__path_refit, verbose=False)                                │
# │   1284 │                                                                                         │
# │   1285 │   def get_params(self) -> dict:                                                         │
# │   1286 │   │   """Get params of the model at the time of initialization"""                       │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/timeseries/models/gluont │
# │ s/torch/models.py:118 in load                                                                    │
# │                                                                                                  │
# │   115 │   @classmethod                                                                           │
# │   116 │   def load(cls, path: str, reset_paths: bool = True, verbose: bool = True) -> "Abstrac   │
# │   117 │   │   with torch_warning_filter():                                                       │
# │ ❱ 118 │   │   │   model = load_pkl.load(path=path + cls.model_file_name, verbose=verbose)        │
# │   119 │   │   │   if reset_paths:                                                                │
# │   120 │   │   │   │   model.set_contexts(path)                                                   │
# │   121 │   │   │   model.gts_predictor = GluonTSPyTorchPredictor.deserialize(Path(path) / cls.g   │
# │                                                                                                  │
# │ /home/hykhhijk/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/common/loaders/load_pkl. │
# │ py:43 in load                                                                                    │
# │                                                                                                  │
# │   40 │   │   compression_fn_kwargs = {}                                                          │
# │   41 │                                                                                           │
# │   42 │   if compression_fn in compression_fn_map:                                                │
# │ ❱ 43 │   │   with compression_fn_map[compression_fn]["open"](validated_path, "rb", **compress    │
# │   44 │   │   │   object = pickle.load(fin)                                                       │
# │   45 │   else:                                                                                   │
# │   46 │   │   raise ValueError(                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: [Errno 2] No such file or directory:
# 'AutogluonModels/ag-20231114_133632/models/DeepAR/DeepAR/W0_FULLmodel.pkl'

# %%
# seed 고정
pred = predictor.predict(data)
# Out:
# Global seed set to 123
# Model not specified in predict, will default to the model with the best validation score: WeightedEnsemble

# %%
pred
# Out:
#                            mean          0.1          0.2          0.3  \
# item_id timestamp
# TG_A_J  2023-03-04  3244.468938  1636.733881  2257.250796  2667.087394
#         2023-03-05   489.230323 -1034.231322  -510.992127  -134.131960
#         2023-03-06  3210.904281   606.836084  1611.494988  2268.948102
#         2023-03-07  3494.387941   664.325787  1742.157711  2418.036963
#         2023-03-08  3401.077983   399.305990  1442.999626  2237.743145
# ...                         ...          ...          ...          ...
# RD_F_J  2023-03-27   517.827167   -41.095563   207.051938   336.468585
#         2023-03-28   530.396600   -47.472243   224.495850   361.098689
#         2023-03-29   553.831353   -44.464600   211.281755   362.149569
#         2023-03-30   542.249102  -157.934639   193.465837   343.008614
#         2023-03-31   516.875395  -148.736432   164.869651   307.664515
#
#                             0.4          0.5          0.6          0.7  \
# item_id timestamp
# TG_A_J  2023-03-04  3000.819809  3294.884832  3579.818507  3887.724872
#         2023-03-05   187.419483   488.070502   789.419198  1111.829071
#         2023-03-06  2795.663643  3277.361800  3734.604147  4245.924059
#         2023-03-07  2990.243613  3514.855593  4013.353803  4565.900419
#         2023-03-08  2845.768088  3413.253154  3999.851256  4635.811624
# ...                         ...          ...          ...          ...
# RD_F_J  2023-03-27   444.253454   533.713062   621.092043   717.667318
#         2023-03-28   459.692649   551.558953   647.959133   753.055656
#         2023-03-29   468.921237   570.368951   668.279556   770.641617
#         2023-03-30   456.346733   557.264422   658.351088   762.994322
#         2023-03-31   425.065860   533.171446   645.577906   756.092288
#
#                             0.8          0.9
# item_id timestamp
# TG_A_J  2023-03-04  4240.696968  4728.825943
#         2023-03-05  1489.190057  2013.669971
#         2023-03-06  4879.736791  5854.006658
#         2023-03-07  5260.805794  6291.212425
#         2023-03-08  5322.209073  6414.553955
# ...                         ...          ...
# RD_F_J  2023-03-27   839.469310  1047.080754
#         2023-03-28   886.747392  1061.512284
#         2023-03-29   897.742616  1113.990778
#         2023-03-30   894.684040  1091.728241
#         2023-03-31   881.963491  1092.000811
#
# [1092 rows x 10 columns]

# %%
submission = pd.read_csv(os.path.join(path, './sample_submission.csv'))
submission['answer'] = pred.reset_index()['mean']
submission.loc[ submission['answer'] < 0.0, 'answer'] = 0.0
submission.to_csv('./dacon_submission.csv', index=False)
submission
# Out:
#                    ID       answer
# 0     TG_A_J_20230304  3244.468938
# 1     TG_A_J_20230305   489.230323
# 2     TG_A_J_20230306  3210.904281
# 3     TG_A_J_20230307  3494.387941
# 4     TG_A_J_20230308  3401.077983
# ...               ...          ...
# 1087  RD_F_J_20230327   517.827167
# 1088  RD_F_J_20230328   530.396600
# 1089  RD_F_J_20230329   553.831353
# 1090  RD_F_J_20230330   542.249102
# 1091  RD_F_J_20230331   516.875395
#
# [1092 rows x 2 columns]
